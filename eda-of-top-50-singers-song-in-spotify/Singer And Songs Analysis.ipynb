# %% [markdown]
# # <center><b>Analysis of Top 50 Indian Singers song data from Spotify<b></center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# **1.** [**Introduction**](#Section1)<br>
# **2.** [**Problem Statement**](#Section2)<br>
# **3.** [**Installing & Importing Libraries**](#Section3)<br>
#   - **3.1** [**Installing Libraries**](#Section31)
#   - **3.2** [**Upgrading Libraries**](#Section32)
#   - **3.3** [**Importing Libraries**](#Section33)
#
# **4.** [**Data Acquisition & Description**](#Section4)<br>
#   - **4.1** [**Data Description**](#Section41)
#   - **4.2** [**Data Information**](#Section42)
#
# **5.** [**Data Pre-processing**](#Section5)<br>
#   - **5.1** [**Handling of Missing Data**](#Section51)
#   - **5.2** [**Handling of Redundant Data**](#Section52)
#   - **5.3** [**Handling of Inconsistent Data**](#Section53)
#   - **5.4** [**Handling of Outliers**](#Section54)
#
# **6.** [**Exploratory Data Analysis**](#Section6)<br>
# **7.** [**Summarization**](#Section7)<br>
#   - **7.1** [**Conclusion**](#Section71)<br>
#   - **7.2** [**Actionable Insights**](#Section72)<br>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# - **Spotify** is a Swedish audio streaming and media services provider founded on 23 April 2006 by **Daniel Ek** and **Martin Lorentzon**.
#
# - It is the world's largest music streaming service providers, with over 365 million monthly active users, including 165 million paying subscribers, as of June 2021.
#
# - In Spotify's apps, music can be browsed or searched for via various parameters, such as artist, album, genre, playlist, or record label. Users can create, edit and share playlists, share tracks on social media, and make playlists with other users.
#
# - One of the main reasons for Spotify’s rapid growth is its ability to provide personalized song recommendations that are often actually useful! When a person tends to like songs with a specific set of audio properties, Spotify will recommend songs with similar properties.
#
# <center><img width=60% src="android-gfdfefe7bd_640.jpg"></center>
#
# - Every song that you listen to can be analyzed based on its unique features—acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, and valence.
#
# - For every track on their platform, Spotify provides data for these Audio Features.
#
# - Spotify uses these features to power products like Spotify Radio and custom playlists like Discover Weekly and Daily Mixes.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - It’s likely that **Spotify** uses these features to power products like **Spotify Radio** and custom playlists like **Discover Weekly** and **Daily Mixes**.
#
# - As a **subscription platform**, Spotify cares about two main elements: **acquiring more users** (moving them from free users to paid users) and **retaining current paid users** in order to capture value.
#
# - It is extremely important to ensure that all the options seen by the users on the home screen make sense, grab their attention, and cover all the potential actions that they are more likely to take.
#
# - The better Spotify can quantify music, the better they can tune their systems and algorithms to generate more revenue for themselves and their stakeholders.
#
# - The **main purposes** of the analysis are as follows:
#
#   - Get easy insight in audio features of **Spotify content**.
#
#   - Analyze each feature for all the artists.
#
#   - See if there are any relationships between the features.
#
#   - Compare the musical vibes of all the artists.
#
#   - Track and compare the positivity rate among the artists.

# %% [markdown]
# ---
# <a name = Section3></a>
# # **3. Installing and Importing Libraries**
# ---

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Installing Libraries**

# %%
# A package that is required by pandas-profiling library
# !pip install -q datascience    
# Library to generate basic statistics about data
# !pip install -q pandas-profiling
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Saoni\\anaconda3\\Lib\\site-packages\\~arkupsafe\\_speedups.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell above (3.1) and below (3.2) again after restarting the runtime.

# %%
# Package that is required by pandas profiling
# !pip install -q --upgrade datascience    
# Library to generate basic statistics about data
# !pip install -q --upgrade pandas-profiling
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# pandas-profiling 3.1.0 requires markupsafe~=2.0.1, but you have markupsafe 1.1.1 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# sphinx 4.0.1 requires MarkupSafe<2.0, but you have markupsafe 2.0.1 which is incompatible.

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Importing Libraries**

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing for panel data analysis
import numpy as np                                                  # For numerical python operations
import matplotlib.pyplot as plt  
import seaborn as sns
pd.set_option('display.max_columns', None)                          # Unfolding hidden features if the cardinality is high
pd.set_option('display.max_colwidth', None)                         # Unfolding the max feature width for better clearity
pd.set_option('display.max_rows', None)                             # Unfolding hidden data points if the cardinality is high
pd.set_option('mode.chained_assignment', None)                      # Removing restriction over chained assignments operations
#-------------------------------------------------------------------------------------------------------------------------------
import plotly.graph_objs as go                                      # For interactive graphs
#-------------------------------------------------------------------------------------------------------------------------------
#import warnings                                                     # Importing warning to disable runtime warnings
#warnings.filterwarnings("ignore")                                   # Warnings will appear only once

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This dataset is obtained from Kaggle in 2021.
#
# - It describes the information about the top 50 singers' song data from Spotify.
#
# | Records | Features | Dataset Size |
# | :-- | :-- | :-- |
# | 2231 | 15 | 386 KB|
#
#
# | Id | Features | Description |
# | :-- | :--| :--|
# |01|**Singer**|Name of the singer.|
# |02|**acousticness**|A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.|
# |03|**danceability**|Describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. It is measured on a scale of 0 (low danceability) to 100 (high danceability).|
# |04|**energy**|measures the perceived intensity and activity of a song. It is also measured on a scale of 0 (low energy) to 100 (high energy).|
# |05|**id**|The Spotify ID for the track.|
# |06|**instrumentalness**|Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. |
# |07|**key**|The estimated overall key of the track. |
# |08|**liveness**|Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.|
# |09|**loudness**|measures the decibel level of a song. Decibels are relative to a reference value, so songs with lower loudness values are quieter relative to the reference value of 0.|
# |10|**mode**|Indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.|
# |11|**Song name**|Name of the track.|
# |12|**speechiness**|Measures the presence of spoken words in a song. Speechiness is measured on a scale of 0 (low speechiness) to 100 (high speechiness).|
# |13|**tempo**|The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece, and derives directly from the average beat duration.|
# |14|**track_href**|The link of the track.|
# |15|**valence**|A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (for example happy, cheerful, euphoric), while tracks with low valence sound more negative (for example sad, depressed, angry).|

# %%
# Data for Top 50 Indian Artists "This is" Playlist from Spotify
df = pd.read_csv("SingerAndSongs.csv")
print('Spotify Top 50 Indian Artists Data Shape:', df.shape)
#df[df["Singer"]=='Asha Bhosle']
# Out:
# Spotify Top 50 Indian Artists Data Shape: (2231, 15)

# %%
# Output top 5 rows
df.head()
# Out:
#         Singer  acousticness  danceability  energy                      id  \
# 0  Aastha Gill       0.48500         0.770   0.824  39ujbBjTwwqUFySaCYDMMT
# 1  Aastha Gill       0.14300         0.825   0.666  5cjVsWqIkBQC7acTRhL0RO
# 2  Aastha Gill       0.23600         0.663   0.551  3XYvdqcZrTmRntFDDbJkJd
# 3  Aastha Gill       0.00323         0.919   0.571  46GBoFCdFZZSjuGaZjZmGv
# 4  Aastha Gill       0.12900         0.867   0.720  6VwVEIiCro1EMyh9B6Om3v
#
#    instrumentalness  key  liveness  loudness  mode             Song name  \
# 0          0.000000    1    0.3180    -6.491     0         Proper Patola
# 1          0.000003    4    0.2370    -4.847     0              Kamariya
# 2          0.000036    3    0.0923    -8.272     0  Buzz (feat. Badshah)
# 3          0.001680    5    0.1030    -7.175     0           Saara India
# 4          0.000000    9    0.2280    -5.188     0          Drunk n High
#
#    speechiness    tempo  \
# 0       0.0851  172.006
# ...

# %% [markdown]
# <a name = Section42></a>
# ### **4.2 Data Information**
#
# - In this section we will see the **information about the types of features**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231 entries, 0 to 2230
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Singer            2231 non-null   object
#  1   acousticness      2231 non-null   float64
#  2   danceability      2231 non-null   float64
#  3   energy            2231 non-null   float64
#  4   id                2231 non-null   object
#  5   instrumentalness  2231 non-null   float64
#  6   key               2231 non-null   int64
#  7   liveness          2231 non-null   float64
#  8   loudness          2231 non-null   float64
#  9   mode              2231 non-null   int64
#  10  Song name         2230 non-null   object
#  11  speechiness       2231 non-null   float64
#  12  tempo             2231 non-null   float64
#  13  track_href        2231 non-null   object
#  14  valence           2231 non-null   float64
# dtypes: float64(9), int64(2), object(4)
# ...

# %% [markdown]
# **Observation:**
#
# - We can observe that there is one missing data in **Song name** in our dataset.
# - As **Song name** is not so important in this dataset, so we keep it as it is.
# - Other than the first point, there are no **inconsistent data type** found in the dataset.

# %% [markdown]
# <a name = Section41></a>
# ### **4.1 Data Description**
#
# - In this section we will get **information about the data** and see some observations.

# %%
df.describe()
# Out:
#        acousticness  danceability       energy  instrumentalness          key  \
# count   2231.000000   2231.000000  2231.000000       2231.000000  2231.000000
# mean       0.396178      0.612732     0.658173          0.011951     5.396683
# std        0.296341      0.156026     0.190023          0.078426     3.459693
# min        0.000266      0.156000     0.103000          0.000000     0.000000
# 25%        0.118000      0.505000     0.520000          0.000000     2.000000
# 50%        0.344000      0.622000     0.669000          0.000007     6.000000
# 75%        0.647500      0.734000     0.815500          0.000249     8.000000
# max        0.994000      0.971000     0.988000          0.967000    11.000000
#
#           liveness     loudness         mode  speechiness        tempo  \
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000
# mean      0.184136    -7.250929     0.573734     0.074873   115.488944
# ...

# %% [markdown]
# **Observations:**
#
# > **Acousticness:**
#
# - This feature ranges from **0.000266 to 0.994000** per track which goes well with the acousticness definition which can vary from 0.0 to 1.0.
# - The average acousticness of all the songs is 0.396178.
# - 25% of the songs acousticness is 0.118000.
# - 50% of the songs acousticness is 0.344000.
# - 75% of the songs acousticness is 0.647500.
#
# > **Danceability:**
#
# - This feature ranges from **0.156000 to 0.971000** per track which goes well with the danceability definition which can vary from 0.0 to 1.0.
# - The average danceability of all the songs is 0.612732.
# - 25% of the songs danceability is 0.505000.
# - 50% of the songs danceability is 0.622000.
# - 75% of the songs danceability is 0.734000.
#
# > **Energy:**
#
# - This feature ranges from **0.103000 to 0.988000** per track which goes well with the energy definition which can vary from 0.0 to 1.0.
# - The average energy of all the songs is 0.658173.
# - 25% of the songs energy is 0.520000.
# - 50% of the songs energy is 0.669000.
# - 75% of the songs energy is 0.815500.
#
# > **Instrumentalness:**
#
# - This feature ranges from **0.000000 to 0.967000** per track which goes well with the instrumentalness definition which can vary from 0.0 to 1.0.
# - The average instrumentalness of all the songs is 0.011951.
# - 25% of the songs instrumentalness is 0.000000.
# - 50% of the songs instrumentalness is 0.000007.
# - 75% of the songs instrumentalness is 0.000249.
#
# > **Key:**
#
# - All keys on octave encoded as values ranging from 0 to 11, so we won't be making any statistical observations for it as it is considered as a categorical variable.
#
# > **Liveness:**
#
# - This feature ranges from **0.022200 to 0.972000** per track which goes well with the liveness definition which can vary from 0.0 to 1.0.
# - The average liveness of all the songs is 0.184136.
# - 25% of the songs liveness is 0.094800.
# - 50% of the songs liveness is 0.126000.
# - 75% of the songs liveness is 0.245500.
#
# > **Loudness:**
#
# - This feature ranges from **-20.090000 to 0.003000** per track which goes well with the loudness definition which can vary from -60 to 0 db.
# - The average loudness of all the songs is -7.250929.
# - 25% of the songs loudness is -8.841500.
# - 50% of the songs loudness is -6.887000.
# - 75% of the songs loudness is -5.332500.
#
# > **Mode:**
#
# - Major is represented by 1 and minor is 0. So we won't be making any statistical observations for it as it is considered as a categorical variable.
#
# > **Speechiness:**
#
# - This feature ranges from **0.023200 to 0.684000** per track which goes well with the speechiness definition which can vary from 0.0 to 1.0.
# - The average speechiness of all the songs is 0.074873.
# - 25% of the songs speechiness is 0.034200.
# - 50% of the songs speechiness is 0.048300.
# - 75% of the songs speechiness is 0.081350.
#
# > **Tempo:**
#
# - This feature ranges from **55.832000 to 214.016000** per track which goes well with the tempo definition.
# - The average tempo of all the songs is 115.488944.
# - 25% of the songs tempo is 95.987000.
# - 50% of the songs tempo is 109.982000.
# - 75% of the songs tempo is 130.098000.
#
# > **Valence:**
#
# - This feature ranges from **0.039400 to 0.970000** per track which goes well with the valence definition which can vary from 0.0 to 1.0.
# - The average valence of all the songs is 0.558418.
# - 25% of the songs valence is 0.385000.
# - 50% of the songs valence is 0.563000.
# - 75% of the songs valence is 0.731000.

# %% [markdown]
# <a name = Section5></a>
#
# ---
# # **5. Data Pre-Processing**
# ---

# %% [markdown]
# <a name = Section51></a>
# ### **5.1 Handling of Missing Data**
#
# - In this section, we will identify missing data and check the proportion of it and take appropriate measures.

# %%
df.isnull().sum()
# Out:
# Singer              0
# acousticness        0
# danceability        0
# energy              0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# Song name           1
# speechiness         0
# tempo               0
# track_href          0
# valence             0
# dtype: int64

# %%
df[df["Song name"].isnull()]
# Out:
#           Singer  acousticness  danceability  energy                      id  \
# 421  Asha Bhosle         0.613         0.314   0.413  43sHEf7MgqOhuNISDoobs0
#
#      instrumentalness  key  liveness  loudness  mode Song name  speechiness  \
# 421             0.118    2     0.109   -11.809     0       NaN       0.0365
#
#       tempo                                                track_href  valence
# 421  73.985  https://api.spotify.com/v1/tracks/43sHEf7MgqOhuNISDoobs0     0.36

# %% [markdown]
# - As **Song name** is not so important in this dataset, so we keep it as it is.

# %% [markdown]
# <a name = Section52></a>
# ### **5.2 Handling of Redundant Data**
#
# - In this section, we will identify redundant data and check the proportion of it and take appropriate measures.

# %%
print('Contains Duplicate Rows?', df.duplicated().sum())
# Out:
# Contains Duplicate Rows? 64

# %%
# Dropping the duplicated rows
df.drop_duplicates(inplace=True)

# %%
# Re-check for duplicated rows
print('Contains Duplicate Rows?', df.duplicated().sum())
# Out:
# Contains Duplicate Rows? 0

# %% [markdown]
# <a name = Section53></a>
# ### **5.3 Handling of Inconsistent Data**
#
# - In this section, we will **identify inconsistency** in data and and then **take appropriate measures**.

# %%
df.Singer.nunique()
# Out:
# 45

# %%
df.id.nunique()
# Out:
# 1891

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 0 to 2230
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Singer            2167 non-null   object
#  1   acousticness      2167 non-null   float64
#  2   danceability      2167 non-null   float64
#  3   energy            2167 non-null   float64
#  4   id                2167 non-null   object
#  5   instrumentalness  2167 non-null   float64
#  6   key               2167 non-null   int64
#  7   liveness          2167 non-null   float64
#  8   loudness          2167 non-null   float64
#  9   mode              2167 non-null   int64
#  10  Song name         2166 non-null   object
#  11  speechiness       2167 non-null   float64
#  12  tempo             2167 non-null   float64
#  13  track_href        2167 non-null   object
#  14  valence           2167 non-null   float64
# dtypes: float64(9), int64(2), object(4)
# ...

# %% [markdown]
# **Observation:**
#
# - We have seen that the dataset was said to be of Top 50 Indian Artist's track details but by investigating we found that there are only 45 unique Singer name in this dataset.
#
# - **id** should also be unique for each and every song but here we have noticed that unique id is less than the total no of rows in tha dataset. Same is with **track_href** field.
#
# - So, it is clear that there is repetiting id in the dataset and we look through this.

# %%
# Selecting duplicate rows based on 'id' column
duplicate = df[df.duplicated('id')]
  
print("Duplicate Rows based on id :")
  
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows based on id :
#                  Singer  acousticness  danceability  energy  \
# 104        Amit Trivedi      0.059300         0.521   0.837
# 146        Ankit Tiwari      0.059300         0.521   0.837
# 180           Anu Malik      0.059300         0.521   0.837
# 189           Anu Malik      0.244000         0.807   0.715
# 255           AR Rahman      0.327000         0.798   0.636
# 272        Arijit Singh      0.635000         0.717   0.416
# 282        Arijit Singh      0.103000         0.625   0.848
# 330        Arijit Singh      0.788000         0.454   0.505
# 332        Arijit Singh      0.702000         0.430   0.437
# 377        Armaan Malik      0.271000         0.707   0.727
# 396         Asha Bhosle      0.103000         0.625   0.848
# 469          Atif aslam      0.093300         0.508   0.761
# 473          Atif aslam      0.332000         0.595   0.610
# 501          Atif aslam      0.271000         0.707   0.727
# ...

# %%
df[df['id']=='2fsPrE2NYiHOHPMuWbjvTj']
# Out:
#                 Singer  acousticness  danceability  energy  \
# 53         Alka Yagnik         0.327         0.798   0.636
# 255          AR Rahman         0.327         0.798   0.636
# 1906  Sukhwinder Singh         0.327         0.798   0.636
#
#                           id  instrumentalness  key  liveness  loudness  mode  \
# 53    2fsPrE2NYiHOHPMuWbjvTj               0.0    6     0.128    -10.52     1
# 255   2fsPrE2NYiHOHPMuWbjvTj               0.0    6     0.128    -10.52     1
# 1906  2fsPrE2NYiHOHPMuWbjvTj               0.0    6     0.128    -10.52     1
#
#        Song name  speechiness   tempo  \
# 53    Ramta Jogi       0.0431  139.98
# 255   Ramta Jogi       0.0431  139.98
# 1906  Ramta Jogi       0.0431  139.98
#
#                                                     track_href  valence
# 53    https://api.spotify.com/v1/tracks/2fsPrE2NYiHOHPMuWbjvTj    0.799
# 255   https://api.spotify.com/v1/tracks/2fsPrE2NYiHOHPMuWbjvTj    0.799
# ...

# %% [markdown]
# **Observation:**
#
# - We realised that one song can be sung by various artists, so that the id & track_href fields are appearing more than once in this dataset.
#
# - Our observation in this step is that there are not 50 singers' data given.

# %% [markdown]
# <a name = Section54></a>
# ### **5.4 Handling of Outliers**
#
# - We haven't found any significant absurd values from the describe method so we can disregard this step.

# %% [markdown]
# <a name = Section6></a>
#
# ---
# # **6. Exploratory Data Analysis**
# ---

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the acousticness of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
#df.groupby('Singer')['acousticness'].nunique().plot(kind='bar')
#for i in range(len(df['acousticness'])):
#    plt.text(i,df['Singer'][i],df['Singer'][i])
#plt.figure(figsize=(20,5))
#df.groupby('Singer')['acousticness'].nunique().plot(kind='bar')
plt.figure(figsize=(15,15))
plt.barh(df['Singer'], df['acousticness'])    
plt.xlabel('Acousticness', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Amit Trivedi, Asha Bhonsle, Kishore Kumar, KK, Lata Mangeshkar, Mahendra Kapoor, Mohammad Rafi, Tulsi Kumar have the most acousticness in their songs.
#
# - Majority of the singers have a moderate level of acousticness, but Raftaar's song is noticably low in acousticness.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the danceability of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['danceability'])    
plt.xlabel('Danceability', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Astha Gill, Badshah, Mika Singh have most danceability in their songs.
#
# - After them we can say that there are Amit Trivedi, Divine, Shaan, Sunidhi Chauhan are the next.
#
# - Majority of the singers have a moderate level, but Kishore Kumar and Ankit Tiwari's song is noticably low in danceability.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the energy of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['energy'])    
plt.xlabel('Energy', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Arijit Singh, Badshah, Himesh Reshammiya, Mika Singh, Neha Kakkar, Tulsi Kumar have most energy in their songs.
#
# - Majority of the singers have a moderate level, but Lata Mangeshkar's song is a bit low in energy.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the instrumentalness of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['instrumentalness'])    
plt.xlabel('Instrumentalness', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Asha Bhonsle, Lata Mangeshkar have most instrumentalness in their songs.
#
# - After them, AR Rahmen, Armaan Malik, Mahammad Rafi, Raftaar have noticably higher instrumentalness in their songs.
#
# - Majority of the singers have low instrumentalness, but Dino James, Divine, Pritams' song have least instrumentalness in their songs.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the liveness of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['liveness'])    
plt.xlabel('Liveness', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Farhan Akhtar, Raftar & Udit Narayan have most liveness in their songs.
#
# - Dino James & KK have least liveness in their songs.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the loudness of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['loudness'])    
plt.xlabel('Loudness', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Loudness', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Anu Malik & Mahendra Kapoor have most loudness in their songs.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the speechiness of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['speechiness'])    
plt.xlabel('Speechiness', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Ankit Tiwari & Divine have most speechiness in their songs.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the tempo of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['tempo'])    
plt.xlabel('Tempo', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - Almost all singers have a moderate level of tempo, but among them, Badshah have the most tempo in his songs.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the valence of each singers in the dataset?</h4>

# %%
# Draw a horizontal bar chart
plt.figure(figsize=(15,20))
plt.barh(df['Singer'], df['valence'])    
plt.xlabel('Valence', fontsize=15)
plt.xticks(fontsize=14)
plt.ylabel('Singer', fontsize=15)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** that almost all singers have a high valence in their songs but Anu Malik, Asha Bhonsle, Badshah, Javed Ali, KK, Kumar Shanu, Monali Thakur, Pritam, Shaan, Sanam, Sunidhi Chauhan have the most positiveness in their songs.
#
# - Almost all singers have a high valence in their songs except Dino James.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the keys used in music in the dataset?</h4>

# %%
a = df.groupby(df['key']).size()
a.plot.pie(autopct="%.2f",figsize=(20,10))
plt.ylabel('Key', fontsize=15)
# Out:
# Text(0, 0.5, 'Key')

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Key 7 and Key 2 is mostly used in the songs.
#
# - Key 3 is least used in the songs listed in the dataset.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we compare the modes of music in the dataset?</h4>

# %%
sns.countplot(x='mode',data=df)
# Out:
# <AxesSubplot:xlabel='mode', ylabel='count'>

# %% [markdown]
# **Observation:**
#
# - We can **observe** that Mode 1 i.e, Major is used more in music than Minor Mode.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we measure if there are any relation between the features of the music in the dataset?</h4>

# %%
corr = df[['acousticness','danceability','energy','instrumentalness','liveness','loudness','speechiness','tempo',
           'valence']].corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observation:**
#
# - We can **observe** that there is a strong co-relation between **energy & loudness**.
#
# - **energy** is positively co-related with **valence**.
#
# - **danceability** is positively co-related with **energy**.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we find the artist with most songs in the dataset?</h4>

# %%
a = df.groupby(df['Singer']).size()
a.plot.barh(figsize=(15,20))
plt.ylabel('Singer', fontsize=15)
plt.xlabel('Songs', fontsize=15)
# Out:
# Text(0.5, 0, 'Songs')

# %% [markdown]
# **Observation:**
#
# - We can **observe** that **Sunidhi Chauhan** has most of the songs in the dataset, followed by **Arijit Singh**.
#
# - **Dino James** has least no. of tracks.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we find the relation between energy and loudness of a song in the dataset?</h4>

# %%
sns.scatterplot(x='energy', y ='loudness' ,
data = df)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='loudness'>

# %% [markdown]
# **Observation:**
#
# - It is clearly visible that **loudness & energy** are directly proportional to each other.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we find the relation between energy and valence of a song in the dataset?</h4>

# %%
sns.scatterplot(x='energy', y ='valence' ,
data = df)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='valence'>

# %% [markdown]
# **Observation:**
#
# - It is clearly visible that **valence & energy** are directly proportional to each other.

# %% [markdown]
# <a name = Section61></a>
# **<h4>Question:** How can we find the relation between energy and danceability of a song in the dataset?</h4>

# %%
sns.scatterplot(x='energy', y ='danceability' ,
data = df)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='danceability'>

# %% [markdown]
# **Observation:**
#
# - It is clearly visible that **danceability & energy** are directly proportional to each other.

# %% [markdown]
# <a name = Section7></a>
#
# ---
# # **7. Summarization**
# ---
#
# - **<h4>Conclusion</h4>**
#
#   - This dataset has **helped** us to **get an insight** about **audio features** of the songs.
#
#   - We have found that there is a direct relationship between **energy & loudness**, **energy & valence** and **energy & danceability**.
#
#   - We have found out about the **audio feature** specialities of each **singer**.
#
#   - We are able to track the positiveness of the singers.
#
#
# -  **<h4>Actionable Insights</h4>**
#
#   - The songs which is loud enough should have the most energy in it.
#
#   - Not all the keys are used equally in a music. It varys.
#
#   - We have foud the singers who have most acousticness, most liveness, most energy, most danceability in their songs, so we can advice the singer's name on the feature demand easily.
